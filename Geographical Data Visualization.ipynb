# %% [markdown]
# <a href="https://colab.research.google.com/github/kewaona/Mining-Programming-Project_Gr35/blob/main/Geographical%20Data%20Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
import pandas as pd

# ====== COUNTRY PROFILES (without Zimbabwe) ======
countries = pd.DataFrame({
    'Country': ['South Africa', 'DRC (Congo)', 'Namibia', 'Mozambique'],
    'Latitude': [-30.5595, -2.8, -22.6, -18.6],
    'Longitude': [22.9375, 23.7, 17.1, 35.5],
    'GDP_BillionUSD': [350, 55, 15, 20],
    'MiningRevenue_BillionUSD': [25, 12, 3, 4],
})

# ====== MAJOR MINERAL DEPOSITS (without Zimbabwe) ======
deposits = pd.DataFrame({
    'Country': [
        'South Africa', 'South Africa', 'DRC (Congo)', 'DRC (Congo)',
        'Namibia', 'Mozambique'
    ],
    'DepositName': [
        'Waterberg Lithium Mine', 'Waterberg Lithium Mine',  # Only the ones relevant after removing Zimbabwe
        'Kolwezi Mine', 'Tenke Fungurume Mine',
        'Otjozondu Manganese', 'Balama Graphite Mine'
    ],
    'Mineral': [
        'Lithium', 'Lithium',
        'Cobalt', 'Copper',
        'Manganese', 'Graphite'
    ],
    'Latitude': [
        -24.5, -24.5,
        -10.7, -6.1,
        -22.0, -13.3
    ],
    'Longitude': [
        28.5, 28.5,
        25.5, 26.4,
        17.2, 38.2
    ],
    'Production_tonnes': [40000, 40000, 95000, 60000, 30000, 12000]
})

# ====== COLOR MAPPING FOR MINERALS ======
mineral_colors = {
    'Lithium': 'blue',
    'Cobalt': 'darkblue',
    'Manganese': 'brown',
    'Graphite': 'gray'
}

# ====== COMBINED MINERAL VISUALIZATION ======
m = folium.Map(location=[-10, 25], zoom_start=3, tiles='cartodb positron')

# --- 1. Add country-level markers (profiles) ---
for _, row in countries.iterrows():
    popup_html = f"""
    <h4 style='color:#007BFF'>{row['Country']}</h4>
    <b>GDP:</b> {row['GDP_BillionUSD']} Billion USD<br>
    <b>Mining Revenue:</b> {row['MiningRevenue_BillionUSD']} Billion USD<br>
    """
    iframe = folium.IFrame(popup_html, width=230, height=100)
    popup = folium.Popup(iframe, max_width=300)

    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup,
        icon=folium.Icon(color='darkblue', icon='flag')
    ).add_to(m)

# --- 2. Add mineral deposit locations (colored by mineral type) ---
for _, row in deposits.iterrows():
    popup_html = f"""
    <b>Deposit:</b> {row['DepositName']}<br>
    <b>Country:</b> {row['Country']}<br>
    <b>Mineral:</b> {row['Mineral']}<br>
    <b>Production:</b> {row['Production_tonnes']} tonnes
    """
    iframe = folium.IFrame(popup_html, width=220, height=110)
    popup = folium.Popup(iframe, max_width=250)

    color = mineral_colors.get(row['Mineral'], 'orange')  # default orange if mineral not in dict

    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=6,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=popup
    ).add_to(m)

# ====== ADD LEGEND ======

# HTML code for the legend (only for Cobalt, Lithium, Graphite, and Manganese)
legend_html = '''
    <div style="position: absolute;
                bottom: 10px; left: 10px; width: 180px; height: 130px;
                background-color: white; opacity: 0.8; padding: 10px;
                font-size: 12px; border-radius: 5px; z-index: 1000; border: 2px solid grey;">
        <h4>Mineral Legend</h4>
        <ul style="list-style-type: none; padding: 0;">
            <li><i style="background-color: blue; padding: 5px;"></i> Lithium</li>
            <li><i style="background-color: darkblue; padding: 5px;"></i> Cobalt</li>
            <li><i style="background-color: brown; padding: 5px;"></i> Manganese</li>
            <li><i style="background-color: gray; padding: 5px;"></i> Graphite</li>
        </ul>
    </div>
'''

# Adding the legend to the map using a DivIcon for fixed positioning
folium.Marker(
    location=[-10, 25],  # This is a dummy location; the legend will appear fixed on the map
    icon=folium.DivIcon(html=legend_html)
).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0553127af207b95a7d5187700d9d5358 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0553127af207b95a7d5187700d9d5358&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0553127af207b95a7d5187700d9d5358 = L.map(
#                 &quot;map_0553127af207b95a7d5187700d9d5358&quot;,
#                 {
#                     center: [-10.0, 25.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b13504a837cd6cb8244d68c0866bd794 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b13504a837cd6cb8244d68c0866bd794.addTo(map_0553127af207b95a7d5187700d9d5358);
#
#
#             var marker_f86b6214867632afcb7f807c08ad640b = L.marker(
#                 [-30.5595, 22.9375],
#                 {
# }
#             ).addTo(map_0553127af207b95a7d5187700d9d5358);
#
#
#             var icon_498fdeec0f1bb8e37caccde40962624a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7c58787572b44e54faac06490c96bf64 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var i_frame_ce59b4b0b8beb866e5c6f3597a4b0286 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoNCBzdHlsZT0nY29sb3I6IzAwN0JGRic+U291dGggQWZyaWNhPC9oND4KICAgIDxiPkdEUDo8L2I+IDM1MCBCaWxsaW9uIFVTRDxicj4KICAgIDxiPk1pbmluZyBSZXZlbnVlOjwvYj4gMjUgQmlsbGlvbiBVU0Q8YnI+CiAgICA=&quot; width=&quot;230&quot; style=&quot;border:none !important;&quot; height=&quot;100&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_7c58787572b44e54faac06490c96bf64.setContent(i_frame_ce59b4b0b8beb866e5c6f3597a4b0286);
#
#
#
#         marker_f86b6214867632afcb7f807c08ad640b.bindPopup(popup_7c58787572b44e54faac06490c96bf64)
#         ;
#
#
#
#
#                 marker_f86b6214867632afcb7f807c08ad640b.setIcon(icon_498fdeec0f1bb8e37caccde40962624a);
#
#
#             var marker_c542d632aad5a1ffeea5c40e1e9203ed = L.marker(
#                 [-2.8, 23.7],
#                 {
# }
#             ).addTo(map_0553127af207b95a7d5187700d9d5358);
#
#
#             var icon_c96c2bca00ec537b2c5ae2e133698a6d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_600883df0b0cec375053e37399f59197 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var i_frame_dadf10424c67b6ef1f517a3ea9e5593b = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoNCBzdHlsZT0nY29sb3I6IzAwN0JGRic+RFJDIChDb25nbyk8L2g0PgogICAgPGI+R0RQOjwvYj4gNTUgQmlsbGlvbiBVU0Q8YnI+CiAgICA8Yj5NaW5pbmcgUmV2ZW51ZTo8L2I+IDEyIEJpbGxpb24gVVNEPGJyPgogICAg&quot; width=&quot;230&quot; style=&quot;border:none !important;&quot; height=&quot;100&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_600883df0b0cec375053e37399f59197.setContent(i_frame_dadf10424c67b6ef1f517a3ea9e5593b);
#
#
#
#         marker_c542d632aad5a1ffeea5c40e1e9203ed.bindPopup(popup_600883df0b0cec375053e37399f59197)
#         ;
#
#
#
#
#                 marker_c542d632aad5a1ffeea5c40e1e9203ed.setIcon(icon_c96c2bca00ec537b2c5ae2e133698a6d);
#
#
#             var marker_9c5c055c14b9db43386280c158399c4c = L.marker(
#                 [-22.6, 17.1],
#                 {
# }
#             ).addTo(map_0553127af207b95a7d5187700d9d5358);
#
#
#             var icon_cc1c546f954ec93e9633ea690f44d425 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_91027e34ae1ac38a61b89b5d1e605c52 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var i_frame_69c68ee770291332d80bb7d2cac5cc09 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoNCBzdHls

# %%
import folium
import pandas as pd

# ====== COUNTRY PROFILES (without Zimbabwe) ======
countries = pd.DataFrame({
    'Country': ['South Africa', 'DRC (Congo)', 'Namibia', 'Mozambique'],
    'Latitude': [-30.5595, -2.8, -22.6, -18.6],
    'Longitude': [22.9375, 23.7, 17.1, 35.5],
    'GDP_BillionUSD': [350, 55, 15, 20],
    'MiningRevenue_BillionUSD': [25, 12, 3, 4],
})

# ====== MAJOR MINERAL DEPOSITS (without Zimbabwe and Tenke Fungurume Mine) ======
deposits = pd.DataFrame({
    'Country': [
        'South Africa', 'South Africa', 'DRC (Congo)',
        'Namibia', 'Mozambique'
    ],
    'DepositName': [
        'Waterberg Lithium Mine', 'Waterberg Lithium Mine',  # Only the relevant ones
        'Kolwezi Mine',
        'Otjozondu Manganese', 'Balama Graphite Mine'
    ],
    'Mineral': [
        'Lithium', 'Lithium',
        'Cobalt',
        'Manganese', 'Graphite'
    ],
    'Latitude': [
        -24.5, -24.5,
        -10.7,
        -22.0, -13.3
    ],
    'Longitude': [
        28.5, 28.5,
        25.5,
        17.2, 38.2
    ],
    'Production_tonnes': [40000, 40000, 95000, 30000, 12000]
})

# ====== COLOR MAPPING FOR MINERALS ======
mineral_colors = {
    'Lithium': 'blue',
    'Cobalt': 'darkblue',
    'Manganese': 'brown',
    'Graphite': 'gray'
}

# ====== COMBINED MINERAL VISUALIZATION ======
m = folium.Map(location=[-10, 25], zoom_start=3, tiles='cartodb positron')

# --- 1. Add country-level markers (profiles) ---
for _, row in countries.iterrows():
    popup_html = f"""
    <h4 style='color:#007BFF'>{row['Country']}</h4>
    <b>GDP:</b> {row['GDP_BillionUSD']} Billion USD<br>
    <b>Mining Revenue:</b> {row['MiningRevenue_BillionUSD']} Billion USD<br>
    """
    iframe = folium.IFrame(popup_html, width=230, height=100)
    popup = folium.Popup(iframe, max_width=300)

    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup,
        icon=folium.Icon(color='darkblue', icon='flag')
    ).add_to(m)

# --- 2. Add mineral deposit locations (colored by mineral type) ---
for _, row in deposits.iterrows():
    popup_html = f"""
    <b>Deposit:</b> {row['DepositName']}<br>
    <b>Country:</b> {row['Country']}<br>
    <b>Mineral:</b> {row['Mineral']}<br>
    <b>Production:</b> {row['Production_tonnes']} tonnes
    """
    iframe = folium.IFrame(popup_html, width=220, height=110)
    popup = folium.Popup(iframe, max_width=250)

    color = mineral_colors.get(row['Mineral'], 'orange')  # default orange if mineral not in dict

    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=6,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=popup
    ).add_to(m)

# ====== ADD LEGEND ======

# HTML code for the legend (only for Cobalt, Lithium, Graphite, and Manganese)
legend_html = '''
    <div style="position: absolute;
                bottom: 10px; left: 10px; width: 180px; height: 130px;
                background-color: white; opacity: 0.8; padding: 10px;
                font-size: 12px; border-radius: 5px; z-index: 1000; border: 2px solid grey;">
        <h4>Mineral Legend</h4>
        <ul style="list-style-type: none; padding: 0;">
            <li><i style="background-color: blue; padding: 5px;"></i> Lithium</li>
            <li><i style="background-color: darkblue; padding: 5px;"></i> Cobalt</li>
            <li><i style="background-color: brown; padding: 5px;"></i> Manganese</li>
            <li><i style="background-color: gray; padding: 5px;"></i> Graphite</li>
        </ul>
    </div>
'''

# Adding the legend to the map using a DivIcon for fixed positioning
folium.Marker(
    location=[-10, 25],  # This is a dummy location; the legend will appear fixed on the map
    icon=folium.DivIcon(html=legend_html)
).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49d054625d3203b962fd7431b0f6a146 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49d054625d3203b962fd7431b0f6a146&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49d054625d3203b962fd7431b0f6a146 = L.map(
#                 &quot;map_49d054625d3203b962fd7431b0f6a146&quot;,
#                 {
#                     center: [-10.0, 25.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04be74234e816237e9aa4bb5a6ad0a99 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04be74234e816237e9aa4bb5a6ad0a99.addTo(map_49d054625d3203b962fd7431b0f6a146);
#
#
#             var marker_30f8c924dfa20ca5a5dc5cd47c0b7719 = L.marker(
#                 [-30.5595, 22.9375],
#                 {
# }
#             ).addTo(map_49d054625d3203b962fd7431b0f6a146);
#
#
#             var icon_0a7575c91b01b23c802c8756855b74fd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_64388d68fdbaf524a7d813dd846c70d7 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var i_frame_410a36732fae095438336937b8cb28fa = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoNCBzdHlsZT0nY29sb3I6IzAwN0JGRic+U291dGggQWZyaWNhPC9oND4KICAgIDxiPkdEUDo8L2I+IDM1MCBCaWxsaW9uIFVTRDxicj4KICAgIDxiPk1pbmluZyBSZXZlbnVlOjwvYj4gMjUgQmlsbGlvbiBVU0Q8YnI+CiAgICA=&quot; width=&quot;230&quot; style=&quot;border:none !important;&quot; height=&quot;100&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_64388d68fdbaf524a7d813dd846c70d7.setContent(i_frame_410a36732fae095438336937b8cb28fa);
#
#
#
#         marker_30f8c924dfa20ca5a5dc5cd47c0b7719.bindPopup(popup_64388d68fdbaf524a7d813dd846c70d7)
#         ;
#
#
#
#
#                 marker_30f8c924dfa20ca5a5dc5cd47c0b7719.setIcon(icon_0a7575c91b01b23c802c8756855b74fd);
#
#
#             var marker_b0a6aaf88b04bc4e01ddf077559a6a8a = L.marker(
#                 [-2.8, 23.7],
#                 {
# }
#             ).addTo(map_49d054625d3203b962fd7431b0f6a146);
#
#
#             var icon_5f85f7f69ed5c7c2ba661e16f9c9ab69 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7da54b91d0e706108fdb65ac928fe804 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var i_frame_5f871a1ed1c10b03a0618394ff3405c1 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoNCBzdHlsZT0nY29sb3I6IzAwN0JGRic+RFJDIChDb25nbyk8L2g0PgogICAgPGI+R0RQOjwvYj4gNTUgQmlsbGlvbiBVU0Q8YnI+CiAgICA8Yj5NaW5pbmcgUmV2ZW51ZTo8L2I+IDEyIEJpbGxpb24gVVNEPGJyPgogICAg&quot; width=&quot;230&quot; style=&quot;border:none !important;&quot; height=&quot;100&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_7da54b91d0e706108fdb65ac928fe804.setContent(i_frame_5f871a1ed1c10b03a0618394ff3405c1);
#
#
#
#         marker_b0a6aaf88b04bc4e01ddf077559a6a8a.bindPopup(popup_7da54b91d0e706108fdb65ac928fe804)
#         ;
#
#
#
#
#                 marker_b0a6aaf88b04bc4e01ddf077559a6a8a.setIcon(icon_5f85f7f69ed5c7c2ba661e16f9c9ab69);
#
#
#             var marker_6dbb8bfab7df7379137eaed261e298da = L.marker(
#                 [-22.6, 17.1],
#                 {
# }
#             ).addTo(map_49d054625d3203b962fd7431b0f6a146);
#
#
#             var icon_e6460b2c9dd4f966c6a6e5367862afad = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8524bc0d706b77d15cdf894bf69e6a40 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var i_frame_f43caf8cbc691a3d843ebe114f897753 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoNCBzdHls
